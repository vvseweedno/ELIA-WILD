# %% [markdown]
# # ELIA WILD — Genesis on Kaggle
#
# This notebook validates the body first, then runs exactly one real Qwen-backed cognitive cycle.

# %%
# !git clone https://github.com/vvseweedno/ELIA-WILD.git
# %cd ELIA-WILD
# !python -m pip install -q -e '.[test]'

# %%
# Zero-GPU body validation first.
# !ELIA_BRAIN=mock pytest
# !ELIA_BRAIN=mock python -m elia --cycles 3
# !python -m elia --verify
# !python -m elia --status

# %%
# Confirm the accelerator before spending quota.
import torch
assert torch.cuda.is_available(), 'Enable a Kaggle GPU accelerator before continuing.'
print(torch.cuda.get_device_name(0))
props = torch.cuda.get_device_properties(0)
print(f'VRAM: {props.total_memory / 1024**3:.2f} GiB')

# %%
# Install the direct 4-bit Qwen backend. This may take several minutes on a fresh image.
# !python -m pip install -q -e '.[gpu]'

# %%
# One real Genesis cycle only.
# The default config uses Qwen/Qwen3.5-9B, 4-bit NF4, float16 compute, thinking disabled.
# !python -m elia --cycles 1

# %%
# Verify continuity artifacts immediately after the first real cycle.
# !python -m elia --verify
# !python -m elia --status
# !tail -n 5 .elia/chronicle.jsonl

# %% [markdown]
# ## Stop here after the first successful GPU cycle
#
# Do not start long unattended runs until Genesis v0.2 implements authenticated checkpoint/restore of `.elia/` across independent Kaggle sessions.
